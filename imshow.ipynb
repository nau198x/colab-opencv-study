# %% [markdown]
# <a href="https://colab.research.google.com/github/nau198x/colab-opencv-study/blob/main/imshow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#サポートパッチのインポート
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread('/content/drive/My Drive/Colab Notebooks/img/lena.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F3B5597A090>
